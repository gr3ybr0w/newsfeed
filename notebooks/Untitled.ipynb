# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

import altair as alt

# %%
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
data_dirs = pd.read_parquet('../data/processed/data_dirs.parquet')

# %%
data_dirs
# Out:
#                                             location instrument_type  \
# 0        ../data/raw/data/daily/world/lme/na_c.f.txt             lme
# 1        ../data/raw/data/daily/world/lme/ah_3.f.txt             lme
# 2        ../data/raw/data/daily/world/lme/zs_3.f.txt             lme
# 3        ../data/raw/data/daily/world/lme/ni_c.f.txt             lme
# 4        ../data/raw/data/daily/world/lme/sn_c.f.txt             lme
# ...                                              ...             ...
# 3063   ../data/raw/data/daily/world/indices/^smi.txt         indices
# 3064  ../data/raw/data/daily/world/indices/^ipsa.txt         indices
# 3065   ../data/raw/data/daily/world/indices/^snx.txt         indices
# 3066   ../data/raw/data/daily/world/indices/^aor.txt         indices
# 3067  ../data/raw/data/daily/world/indices/^cdax.txt         indices
#
#      instrument                        parquet_location
# 0        na_c.f  ../data/processed/stooq/na_c.f.parquet
# ...

# %%
data_dirs['instrument_type'].unique()
# Out:
# array(['lme', 'stooq stocks indices', 'currencies\\major', 'commodities',
#        'bonds', 'currencies\\other', 'commodities cash', 'money market',
#        'cryptocurrencies', 'indices'], dtype=object)

# %%
data_dirs[data_dirs['instrument_type'] == 'lme']['instrument'].unique()
# Out:
# array(['na_c.f', 'ah_3.f', 'zs_3.f', 'ni_c.f', 'sn_c.f', 'sn_3.f',
#        'co_c.f', 'pb_c.f', 'zs_c.f', 'ni_3.f', 'na_3.f', 'ah_c.f',
#        'aa_3.f', 'aa_c.f', 'pb_3.f', 'ca_3.f', 'ca_c.f', 'co_3.f'],
#       dtype=object)

# %%
inst_sel = data_dirs[data_dirs['instrument'] == 'ni_c.f']['parquet_location'].values[0]

# %%
inst_df = pd.read_parquet(inst_sel)

# %%
inst_df
# Out:
#       TICKER PER       DATE  TIME   OPEN   HIGH    LOW  CLOSE  VOL  OPENINT
# 0     NI_C.F   D 1989-01-03     0  18800  18800  18800  18800    0        0
# 1     NI_C.F   D 1989-01-04     0  19150  19150  19150  19150    0        0
# 2     NI_C.F   D 1989-01-05     0  19200  19200  19200  19200    0        0
# 3     NI_C.F   D 1989-01-06     0  17600  17600  17600  17600    0        0
# 4     NI_C.F   D 1989-01-09     0  16000  16000  16000  16000    0        0
# ...      ...  ..        ...   ...    ...    ...    ...    ...  ...      ...
# 8027  NI_C.F   D 2020-10-12     0  15217  15217  15217  15217    0        0
# 8028  NI_C.F   D 2020-10-13     0  15147  15147  15147  15147    0        0
# 8029  NI_C.F   D 2020-10-14     0  15105  15105  15105  15105    0        0
# 8030  NI_C.F   D 2020-10-15     0  15353  15353  15353  15353    0        0
# 8031  NI_C.F   D 2020-10-16     0  15603  15603  15603  15603    0        0
#
# [8032 rows x 10 columns]

# %%
alt.Chart(inst_df, width=1200).mark_line().encode(x='DATE:T', y='CLOSE:Q')
# Out:
# alt.Chart(...)
