# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

import altair as alt

# %%
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
ukx = pd.read_csv('../data/raw/data/daily/world/indices/^ukx.txt', parse_dates=['<DATE>'])

# %%
ukx.columns = [x.replace('<', '').replace('>','') for x in ukx.columns.values]

# %%
ukx
# Out:
#       TICKER PER       DATE  TIME     OPEN     HIGH      LOW    CLOSE  \
# 0       ^UKX   D 1935-11-13     0   125.90   125.90   125.90   125.90
# 1       ^UKX   D 1935-11-14     0   125.70   125.70   125.70   125.70
# 2       ^UKX   D 1935-11-15     0   125.40   125.40   125.40   125.40
# 3       ^UKX   D 1935-11-16     0   125.40   125.40   125.40   125.40
# 4       ^UKX   D 1935-11-18     0   125.40   125.40   125.40   125.40
# ...      ...  ..        ...   ...      ...      ...      ...      ...
# 21683   ^UKX   D 2020-10-12     0  6016.65  6037.08  5995.11  6001.38
# 21684   ^UKX   D 2020-10-13     0  6001.38  6008.04  5949.97  5969.71
# 21685   ^UKX   D 2020-10-14     0  5969.71  6009.81  5926.49  5935.06
# 21686   ^UKX   D 2020-10-15     0  5935.06  5935.06  5786.20  5832.52
# 21687   ^UKX   D 2020-10-16     0  5832.52  5933.81  5832.52  5919.58
#
#              VOL  OPENINT
# 0              0        0
# 1              0        0
# 2              0        0
# ...

# %%
alt.Chart(ukx, width=1200).mark_line().encode(x='DATE:T', y='CLOSE:Q')
# Out:
# alt.Chart(...)
