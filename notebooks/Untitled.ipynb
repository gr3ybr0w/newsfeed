# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

import altair as alt

# %%
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
data_dirs = pd.read_parquet('../data/processed/data_dirs.parquet')

# %%
data_dirs
# Out:
#                                             location instrument_type  \
# 0        ../data/raw/data/daily/world/lme/na_c.f.txt             lme
# 1        ../data/raw/data/daily/world/lme/ah_3.f.txt             lme
# 2        ../data/raw/data/daily/world/lme/zs_3.f.txt             lme
# 3        ../data/raw/data/daily/world/lme/ni_c.f.txt             lme
# 4        ../data/raw/data/daily/world/lme/sn_c.f.txt             lme
# ...                                              ...             ...
# 3063   ../data/raw/data/daily/world/indices/^smi.txt         indices
# 3064  ../data/raw/data/daily/world/indices/^ipsa.txt         indices
# 3065   ../data/raw/data/daily/world/indices/^snx.txt         indices
# 3066   ../data/raw/data/daily/world/indices/^aor.txt         indices
# 3067  ../data/raw/data/daily/world/indices/^cdax.txt         indices
#
#      instrument                        parquet_location
# 0        na_c.f  ../data/processed/stooq/na_c.f.parquet
# ...

# %%
df = pd.read_parquet(data_dirs.loc[4, 'parquet_location'])

# %%
df
# Out:
#       TICKER PER       DATE  TIME   OPEN   HIGH    LOW  CLOSE  VOL  OPENINT
# 0     SN_C.F   D 1989-07-03     0   9950   9950   9950   9950    0        0
# 1     SN_C.F   D 1989-07-04     0   9980   9980   9980   9980    0        0
# 2     SN_C.F   D 1989-07-05     0  10020  10020  10020  10020    0        0
# 3     SN_C.F   D 1989-07-06     0  10110  10110  10110  10110    0        0
# 4     SN_C.F   D 1989-07-07     0  10015  10015  10015  10015    0        0
# ...      ...  ..        ...   ...    ...    ...    ...    ...  ...      ...
# 7902  SN_C.F   D 2020-10-12     0  18275  18275  18275  18275    0        0
# 7903  SN_C.F   D 2020-10-13     0  18320  18320  18320  18320    0        0
# 7904  SN_C.F   D 2020-10-14     0  18225  18225  18225  18225    0        0
# 7905  SN_C.F   D 2020-10-15     0  18343  18343  18343  18343    0        0
# 7906  SN_C.F   D 2020-10-16     0  18390  18390  18390  18390    0        0
#
# [7907 rows x 10 columns]

# %%
alt.Chart(df, width=1200).mark_line().encode(x='DATE:T', y='CLOSE:Q')
# Out:
# alt.Chart(...)
